# %% [markdown]
# ## A very trivial linear regression test

# %%
# %run src.ipynb

x = np.arange(0,10,1)
y = 2*x+1+np.random.rand(x.size)
x = np.reshape(x,(-1,1))

w0 = 0
b0 = 0
alpha = 0.01
numberIterations = 2000
w,b,_ = gradient_descent(x,y,w0,b0,alpha,numberIterations,linear_regression_cost,linear_regression_gradient);
print(f"w = {w}, b = {b}")
yhat = prediction_linear_regression(w,b,x)
plt.scatter(x,y,marker='^',c='r',label='training data')
plt.plot(x,yhat,'-b',label='model')
plt.xlabel('$x$')
plt.ylabel('$y$')
plt.legend(frameon=False)
# Out:
# Iteration 0: Cost = [35.75290016]
# Iteration 200: Cost = [0.07843872]
# Iteration 400: Cost = [0.04238183]
# Iteration 600: Cost = [0.03074651]
# Iteration 800: Cost = [0.02699187]
# Iteration 1000: Cost = [0.02578027]
# Iteration 1200: Cost = [0.02538929]
# Iteration 1400: Cost = [0.02526313]
# Iteration 1600: Cost = [0.02522241]
# Iteration 1800: Cost = [0.02520928]
# w = [2.00664219], b = [1.41390508]
