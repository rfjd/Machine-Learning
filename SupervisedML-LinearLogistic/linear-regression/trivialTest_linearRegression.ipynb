# %% [markdown]
# ## A very trivial linear regression test

# %%
# %run ../src.ipynb

x = np.arange(0,10,1)
y = 2*x+1+np.random.rand(x.size)
x = np.reshape(x,(-1,1))

w0 = 0
b0 = 0
alpha = 0.01
numberIterations = 2000
w,b,_ = gradient_descent(x,y,w0,b0,alpha,numberIterations,linear_regression_cost,linear_regression_gradient);
print(f"w = {w}, b = {b}")
yhat = prediction_linear_regression(w,b,x)
plt.scatter(x,y,marker='^',c='r',label='training data')
plt.plot(x,yhat,'-b',label='model')
plt.xlabel('$x$')
plt.ylabel('$y$')
plt.legend(frameon=False)
plt.show()
# Out:
# Iteration      0: Cost = 35.85953
# Iteration    200: Cost = 0.07887
# Iteration    400: Cost = 0.05457
# Iteration    600: Cost = 0.04673
# Iteration    800: Cost = 0.04420
# Iteration   1000: Cost = 0.04339
# Iteration   1200: Cost = 0.04312
# Iteration   1400: Cost = 0.04304
# Iteration   1600: Cost = 0.04301
# Iteration   1800: Cost = 0.04300
# w = [2.04147526], b = [1.22352365]
