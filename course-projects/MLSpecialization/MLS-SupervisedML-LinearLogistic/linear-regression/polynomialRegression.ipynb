# %% [markdown]
# ## Polynomial regression

# %% [markdown]
# ### Quadratic training data

# %%
# %run ../src.ipynb

x = np.linspace(0,10,20)
y = np.power(x,2)+1+np.random.rand(x.size)
xPolynomial = np.c_[x,np.power(x,2),np.power(x,3)]

# feature scaling
mu = np.mean(xPolynomial, axis=0)
sigma = np.std(xPolynomial, axis=0)

xScaled = (xPolynomial-mu)/sigma

m, n = xScaled.shape;
w0 = np.zeros(n)
b0 = 0
alpha = 1e-1
numberIterations = 20000
w,b,J = gradient_descent(xScaled,y,w0,b0,alpha,numberIterations,linear_regression_cost,linear_regression_gradient);
print(f"w = {w}, b = {b}")
yhat = prediction_linear_regression(w,b,xScaled)
plt.scatter(x,y,marker='o',c='r',label='training data')
plt.plot(x,yhat,'-b',label='model')
plt.xlabel('$x$')
plt.ylabel('$y$')
plt.legend(frameon=False)
plt.show()
# Out:
# Iteration      0: Cost = 767.20055
# Iteration   2000: Cost = 0.22768
# Iteration   4000: Cost = 0.15230
# Iteration   6000: Cost = 0.10786
# Iteration   8000: Cost = 0.08166
# Iteration  10000: Cost = 0.06622
# Iteration  12000: Cost = 0.05711
# Iteration  14000: Cost = 0.05175
# Iteration  16000: Cost = 0.04858
# Iteration  18000: Cost = 0.04672
# w = [ 1.57709501 27.37196445  2.61316565], b = 35.75390607587673

# %% [markdown]
# ### Sinusoidal training data

# %%
x = np.linspace(0,1,100)
y = np.sin(2*np.pi*x)+0.1*np.random.rand(x.size)
xPolynomial = np.c_[x,np.power(x,2),np.power(x,3),np.power(x,4),np.power(x,5),np.power(x,6),np.power(x,7)]

# feature scaling
mu = np.mean(xPolynomial, axis=0)
sigma = np.std(xPolynomial, axis=0)

xScaled = (xPolynomial-mu)/sigma

m, n = xScaled.shape;
w0 = np.zeros(n)
b0 = 0
alpha = 1e-1
numberIterations = 20000
w,b,J = gradient_descent(xScaled,y,w0,b0,alpha,numberIterations,linear_regression_cost,linear_regression_gradient);
print(f"w = {w}, b = {b}")
yhat = prediction_linear_regression(w,b,xScaled)
plt.scatter(x,y,marker='o',c='r',label='training data')
plt.plot(x,yhat,'-b',label='model')
plt.xlabel('$x$')
plt.ylabel('$y$')
plt.legend(frameon=False)
plt.show()
# Out:
# Iteration      0: Cost = 0.16606
# Iteration   2000: Cost = 0.02052
# Iteration   4000: Cost = 0.01522
# Iteration   6000: Cost = 0.01136
# Iteration   8000: Cost = 0.00853
# Iteration  10000: Cost = 0.00646
# Iteration  12000: Cost = 0.00495
# Iteration  14000: Cost = 0.00384
# Iteration  16000: Cost = 0.00303
# Iteration  18000: Cost = 0.00244
# w = [ 2.33260508 -4.95571552 -1.41072269  1.85179311  2.6269962   1.14064908
#  -1.91736083], b = 0.05179231139256775
