# %% [markdown]
# ## A very trivial linear regression test

# %%
# %run ../../src.ipynb

x = np.arange(0,10,1)
y = 2*x+1+np.random.rand(x.size)
x = np.reshape(x,(-1,1))

w0 = 0
b0 = 0
alpha = 0.01
numberIterations = 2000
w,b,_ = gradient_descent(x,y,w0,b0,alpha,numberIterations,linear_regression_cost,linear_regression_gradient);
print(f"w = {w}, b = {b}")
yhat = prediction_linear_regression(w,b,x)
plt.scatter(x,y,marker='^',c='r',label='training data')
plt.plot(x,yhat,'-b',label='model')
plt.xlabel('$x$')
plt.ylabel('$y$')
plt.legend(frameon=False)
plt.show()
# Out:
# Iteration      0: Cost = 35.15141
# Iteration    200: Cost = 0.06396
# Iteration    400: Cost = 0.03509
# Iteration    600: Cost = 0.02578
# Iteration    800: Cost = 0.02277
# Iteration   1000: Cost = 0.02180
# Iteration   1200: Cost = 0.02149
# Iteration   1400: Cost = 0.02139
# Iteration   1600: Cost = 0.02136
# Iteration   1800: Cost = 0.02134
# w = [2.0071845], b = [1.29892354]
