# %% [markdown]
# ## A very trivial linear regression test

# %%
# %run ../src.ipynb

x = np.arange(0,10,1)
y = 2*x+1+np.random.rand(x.size)
x = np.reshape(x,(-1,1))

w0 = 0
b0 = 0
alpha = 0.01
numberIterations = 2000
w,b,_ = gradient_descent(x,y,w0,b0,alpha,numberIterations,linear_regression_cost,linear_regression_gradient);
print(f"w = {w}, b = {b}")
yhat = prediction_linear_regression(w,b,x)
plt.scatter(x,y,marker='^',c='r',label='training data')
plt.plot(x,yhat,'-b',label='model')
plt.xlabel('$x$')
plt.ylabel('$y$')
plt.legend(frameon=False)
# Out:
# Iteration 0: Cost = [35.82260624]
# Iteration 200: Cost = [0.08626751]
# Iteration 400: Cost = [0.04601593]
# Iteration 600: Cost = [0.03302701]
# Iteration 800: Cost = [0.02883557]
# Iteration 1000: Cost = [0.02748302]
# Iteration 1200: Cost = [0.02704657]
# Iteration 1400: Cost = [0.02690572]
# Iteration 1600: Cost = [0.02686027]
# Iteration 1800: Cost = [0.02684561]
# w = [1.99851416], b = [1.47448802]
