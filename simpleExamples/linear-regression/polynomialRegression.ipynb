# %% [markdown]
# ## Polynomial regression

# %% [markdown]
# ### Quadratic training data

# %%
# %run ../../src.ipynb

x = np.linspace(0,10,20)
y = np.power(x,2)+1+np.random.rand(x.size)
xPolynomial = np.c_[x,np.power(x,2),np.power(x,3)]

# feature scaling
mu = np.mean(xPolynomial, axis=0)
sigma = np.std(xPolynomial, axis=0)

xScaled = (xPolynomial-mu)/sigma

m, n = xScaled.shape;
w0 = np.zeros(n)
b0 = 0
alpha = 1e-1
numberIterations = 20000
w,b,J = gradient_descent(xScaled,y,w0,b0,alpha,numberIterations,linear_regression_cost,linear_regression_gradient);
print(f"w = {w}, b = {b}")
yhat = prediction_linear_regression(w,b,xScaled)
plt.scatter(x,y,marker='o',c='r',label='training data')
plt.plot(x,yhat,'-b',label='model')
plt.xlabel('$x$')
plt.ylabel('$y$')
plt.legend(frameon=False)
plt.show()
# Out:
# Iteration      0: Cost = 762.23344
# Iteration   2000: Cost = 0.29483
# Iteration   4000: Cost = 0.18452
# Iteration   6000: Cost = 0.11949
# Iteration   8000: Cost = 0.08116
# Iteration  10000: Cost = 0.05856
# Iteration  12000: Cost = 0.04523
# Iteration  14000: Cost = 0.03738
# Iteration  16000: Cost = 0.03275
# Iteration  18000: Cost = 0.03002
# w = [ 0.40110373 30.70513962  0.27438293], b = 35.640231516527344

# %% [markdown]
# ### Sinusoidal training data

# %%
x = np.linspace(0,1,100)
y = np.sin(2*np.pi*x)+0.1*np.random.rand(x.size)
xPolynomial = np.c_[x,np.power(x,2),np.power(x,3),np.power(x,4),np.power(x,5),np.power(x,6),np.power(x,7)]

# feature scaling
mu = np.mean(xPolynomial, axis=0)
sigma = np.std(xPolynomial, axis=0)

xScaled = (xPolynomial-mu)/sigma

m, n = xScaled.shape;
w0 = np.zeros(n)
b0 = 0
alpha = 1e-1
numberIterations = 20000
w,b,J = gradient_descent(xScaled,y,w0,b0,alpha,numberIterations,linear_regression_cost,linear_regression_gradient);
print(f"w = {w}, b = {b}")
yhat = prediction_linear_regression(w,b,xScaled)
plt.scatter(x,y,marker='o',c='r',label='training data')
plt.plot(x,yhat,'-b',label='model')
plt.xlabel('$x$')
plt.ylabel('$y$')
plt.legend(frameon=False)
plt.show()
# Out:
# Iteration      0: Cost = 0.16468
# Iteration   2000: Cost = 0.02042
# Iteration   4000: Cost = 0.01515
# Iteration   6000: Cost = 0.01130
# Iteration   8000: Cost = 0.00849
# Iteration  10000: Cost = 0.00643
# Iteration  12000: Cost = 0.00493
# Iteration  14000: Cost = 0.00383
# Iteration  16000: Cost = 0.00303
# Iteration  18000: Cost = 0.00244
# w = [ 2.31934154 -4.94604209 -1.39276923  1.85600115  2.614056    1.12513678
#  -1.91195804], b = 0.049551974677097134
