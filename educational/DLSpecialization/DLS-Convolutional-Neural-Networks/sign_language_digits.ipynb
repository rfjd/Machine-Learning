# %% [markdown]
# # <span style="color:blue"> Sign language digit recognition </span>

# %%
import numpy as np
import h5py
import matplotlib.pyplot as plt
import tensorflow as tf

# %%
loc = './data/'
print(f"load train data:")
train_hdf = h5py.File(loc+'signs_train.h5', 'r')
print(f"list of keys in train dataset: {list(train_hdf.keys())}")
X_train = np.array(train_hdf.get('train_set_x'))
y_train = np.array(train_hdf.get('train_set_y'))
print(f"X_train.shape = {X_train.shape}")
print(f"y_train.shape = {y_train.shape}")

print(f"load test data:")
test_hdf = h5py.File(loc+'signs_test.h5', 'r')
print(f"list of keys in test dataset: {list(test_hdf.keys())}")
X_test = np.array(test_hdf.get('test_set_x'))
y_test = np.array(test_hdf.get('test_set_y'))
print(f"X_test.shape = {X_test.shape}")
print(f"y_test.shape = {y_test.shape}")
# Out:
# load train data:
# list of keys in train dataset: ['list_classes', 'train_set_x', 'train_set_y']
# X_train.shape = (1080, 64, 64, 3)
# y_train.shape = (1080,)
# load test data:
# list of keys in test dataset: ['list_classes', 'test_set_x', 'test_set_y']
# X_test.shape = (120, 64, 64, 3)
# y_test.shape = (120,)

# %%
m = X_train.shape[0]
fig, ax = plt.subplots(nrows=2, ncols=8, figsize=(12, 3))
fig.subplots_adjust(wspace=0.1, hspace=0.4)
for a in ax.flat:
    random_index = np.random.randint(m)# pick a random training data
    a.imshow(X_train[random_index])
    a.set_title(y_train[random_index])
    a.set_axis_off()

plt.show()

# %% [markdown]
# # CNN by tf.keras.Sequential

# %%
tfl = tf.keras.layers
model = tf.keras.Sequential([
    tf.keras.Input(shape=X_train.shape[1:],name="data-shape"), # input shape
    tfl.BatchNormalization(axis=-1,name="batch-normalization"), # normalize the data of each channel
    tfl.Conv2D(filters=6, kernel_size=5, strides=1, padding='same', activation='relu',name='conv-layer-1'),# conv layer 1
    tfl.MaxPool2D(pool_size=(2, 2),strides=2,padding='same',name="pool-layer-1"),# max pool 1
    tfl.Conv2D(filters=16, kernel_size=5, strides=1, padding='same', activation='relu',name='conv-layer-2'),# conv layer 2
    tfl.MaxPool2D(pool_size=(2, 2),strides=2,padding='same',name="pool-layer-2"),# max pool 2
    tfl.Flatten(name='flatten'), # flatten the 3D activation
    tfl.Dense(units=120,name='FC-layer-3'),
    tfl.Dense(units=84,name='FC-layer-4'),
    tfl.Dense(units=6, activation='softmax',name='output-layer')
])
model.summary()
# Out:
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  batch-normalization (BatchN  (None, 64, 64, 3)        12
#  ormalization)
#
#  conv-layer-1 (Conv2D)       (None, 64, 64, 6)         456
#
#  pool-layer-1 (MaxPooling2D)  (None, 32, 32, 6)        0
#
#  conv-layer-2 (Conv2D)       (None, 32, 32, 16)        2416
#
#  pool-layer-2 (MaxPooling2D)  (None, 16, 16, 16)       0
#
#  flatten (Flatten)           (None, 4096)              0
#
#  FC-layer-3 (Dense)          (None, 120)               491640
#
#  FC-layer-4 (Dense)          (None, 84)                10164
#
#  output-layer (Dense)        (None, 6)                 510
#
# =================================================================
# Total params: 505,198
# Trainable params: 505,192
# Non-trainable params: 6
# _________________________________________________________________

# %%
tf.keras.utils.plot_model(model, "CNN-sign-language.png")

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(),
              loss=tf.keras.losses.SparseCategoricalCrossentropy(),
              metrics=['accuracy']
)

# %%
model.fit(X_train, y_train, epochs=20, batch_size=32)
# Out:
# Epoch 1/20
# 34/34 [==============================] - 2s 28ms/step - loss: 1.6252 - accuracy: 0.4704
# Epoch 2/20
# 34/34 [==============================] - 1s 27ms/step - loss: 0.5572 - accuracy: 0.8148
# Epoch 3/20
# 34/34 [==============================] - 1s 28ms/step - loss: 0.2547 - accuracy: 0.9185
# Epoch 4/20
# 34/34 [==============================] - 1s 27ms/step - loss: 0.1388 - accuracy: 0.9565
# Epoch 5/20
# 34/34 [==============================] - 1s 28ms/step - loss: 0.0742 - accuracy: 0.9741
# Epoch 6/20
# 34/34 [==============================] - 1s 27ms/step - loss: 0.0234 - accuracy: 0.9963
# Epoch 7/20
# 34/34 [==============================] - 1s 27ms/step - loss: 0.0196 - accuracy: 0.9944
# Epoch 8/20
# 34/34 [==============================] - 1s 27ms/step - loss: 0.0068 - accuracy: 1.0000
# Epoch 9/20
# 34/34 [==============================] - 1s 27ms/step - loss: 0.0033 - accuracy: 1.0000
# Epoch 10/20
# 34/34 [==============================] - 1s 27ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 11/20
# 34/34 [==============================] - 1s 27ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 12/20
# 34/34 [==============================] - 1s 27ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 13/20
# 34/34 [==============================] - 1s 27ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 14/20
# 34/34 [==============================] - 1s 28ms/step - loss: 8.6541e-04 - accuracy: 1.0000
# Epoch 15/20
# 34/34 [==============================] - 1s 27ms/step - loss: 7.9112e-04 - accuracy: 1.0000
# Epoch 16/20
# 34/34 [==============================] - 1s 27ms/step - loss: 6.9124e-04 - accuracy: 1.0000
# Epoch 17/20
# 34/34 [==============================] - 1s 27ms/step - loss: 5.4730e-04 - accuracy: 1.0000
# Epoch 18/20
# 34/34 [==============================] - 1s 27ms/step - loss: 4.8418e-04 - accuracy: 1.0000
# Epoch 19/20
# 34/34 [==============================] - 1s 27ms/step - loss: 4.4613e-04 - accuracy: 1.0000
# Epoch 20/20
# 34/34 [==============================] - 1s 27ms/step - loss: 4.1544e-04 - accuracy: 1.0000

# %% [markdown]
# # Model evaluation by test data

# %%
eval = model.evaluate(X_test, y_test,verbose=0)
print(f"accuracy = {eval[1]*100:.2f}%")
# Out:
# accuracy = 92.50%

# %%
m = X_test.shape[0]
fig, ax = plt.subplots(nrows=2, ncols=8, figsize=(12, 3))
fig.subplots_adjust(wspace=0.1, hspace=0.4)
for a in ax.flat:
    random_index = np.random.randint(m)# pick a random test data
    a.imshow(X_test[random_index])
    probability = model.predict(np.expand_dims(X_test[random_index], axis=0),verbose=0)
    yhat = np.argmax(probability)
    a.set_title(f"{y_test[random_index]}, {yhat}")
    a.set_axis_off()

plt.show()
